# %% [markdown]
# # Preprocessing code

# %% [markdown]
# ## Data Gathering

# %%
# Import Required Libraries
import numpy as np
import matplotlib.pyplot as plt
import requests

# To unzip the edf_dataset
import zipfile
import os

# EDFlib and Data Preprocesing module
from mne.preprocessing import ICA, create_eog_epochs
import mne
from pyedflib import highlevel
import pyedflib as plib

# %%
import requests


def download_file(url, save_path):

    # Check if the file already exists
    if os.path.exists(save_path):
        print(f"File already exists at '{save_path}'. Skipping download.")
        return  # Exit the function if the file exists

    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Open the file in binary write mode and save the content
        with open(save_path, 'wb') as file:
            file.write(response.content)
        print(f"File downloaded successfully and saved to '{save_path}'")
    else:
        print(f"Failed to download file. Status code: {response.status_code}")


# Specify the URL and the path where you want to save the file
url = 'https://figshare.com/ndownloader/articles/4244171/versions/2'
# Change this to your desired path
save_path = '../edf_dataset.zip'

# Call the function to download the file
download_file(url, save_path)
# Out:
# File downloaded successfully and saved to './edf_dataset.zip'

# %%
def unzip_file(zip_file_path, extract_to_folder):

    # Check if the directory exist
    
    if os.path.exists(extract_to_folder):
        print(f"Directory '{extract_to_folder} already exists")
        return # Exit the function if the directory
    
    # Create the directory if it doesn't exist
    os.makedirs(extract_to_folder, exist_ok=True)

    # Open the zip file
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        # Extract all the contents into the specified folder
        zip_ref.extractall(extract_to_folder)


# Specify the path to the zip file and the extraction folder
zip_file_path = '../edf_dataset.zip'
# Change this if needed
extract_to_folder = '../edf_dataset_2'

# Call the function to unzip
unzip_file(zip_file_path, extract_to_folder)

# %%
import os
import re

edf_directory = "./edf_dataset_2"

for filename in os.listdir(edf_directory):
    new_filename = filename

    # Handle spaces in filename
    if ' ' in new_filename:
        new_filename = re.sub(r'\s+', '_', new_filename)

    # Handle subject numbers (S1 -> S01)
    new_filename = re.sub(r'S(\d)(?!\d)', r'S0\1', new_filename)

    # Handle filenames containing '6931959'
    if '6931959' in new_filename:
        new_filename = new_filename.replace('6931959_', '')

    # Handle filenames containing '6921143'
    if '6921143' in new_filename:
        new_filename = new_filename.replace('6921143_', '')

    # Zero-pad other single-digit numbers in filenames
    new_filename = re.sub(r'(?<!\d)(\d)(?!\d)', r'0\1', new_filename)

    # Only rename if the filename has changed
    if new_filename != filename:
        old_file = os.path.join(edf_directory, filename)
        new_file = os.path.join(edf_directory, new_filename)

        os.rename(old_file, new_file)
        print(f'Renamed: "{filename}" to "{new_filename}"')

print("Renaming complete.")
# Out:
# Renamed: "H S7 TASK.edf" to "H_S07_TASK.edf"
# Renamed: "H S6 TASK.edf" to "H_S06_TASK.edf"
# Renamed: "H S16 EO.edf" to "H_S16_EO.edf"
# Renamed: "MDD S17 EC.edf" to "MDD_S17_EC.edf"
# Renamed: "H S13 EC.edf" to "H_S13_EC.edf"
# Renamed: "MDD S12 EO.edf" to "MDD_S12_EO.edf"
# Renamed: "H S5 EC.edf" to "H_S05_EC.edf"
# Renamed: "H S25 EC.edf" to "H_S25_EC.edf"
# Renamed: "MDD S24 EO.edf" to "MDD_S24_EO.edf"
# Renamed: "MDD S24  EC.edf" to "MDD_S24_EC.edf"
# Renamed: "MDD S4 EO.edf" to "MDD_S04_EO.edf"
# Renamed: "MDD S7  EC.edf" to "MDD_S07_EC.edf"
# Renamed: "MDD S33 EC.edf" to "MDD_S33_EC.edf"
# Renamed: "MDD S1 EC.edf" to "MDD_S01_EC.edf"
# Renamed: "MDD S13 TASK.edf" to "MDD_S13_TASK.edf"
# Renamed: "MDD S12 TASK.edf" to "MDD_S12_TASK.edf"
# Renamed: "H S29 EC.edf" to "H_S29_EC.edf"
# Renamed: "H S9 EC.edf" to "H_S09_EC.edf"
# Renamed: "H S20 EO.edf" to "H_S20_EO.edf"
# Renamed: "MDD S28 EO.edf" to "MDD_S28_EO.edf"
# Renamed: "MDD S21 EC.edf" to "MDD_S21_EC.edf"
# Renamed: "MDD S27 TASK.edf" to "MDD_S27_TASK.edf"
# Renamed: "MDD S26 TASK.edf" to "MDD_S26_TASK.edf"
# Renamed: "MDD S19 TASK.edf" to "MDD_S19_TASK.edf"
# Renamed: "MDD S18 TASK.edf" to "MDD_S18_TASK.edf"
# Renamed: "H S22 TASK.edf" to "H_S22_TASK.edf"
# Renamed: "H S23 TASK.edf" to "H_S23_TASK.edf"
# Renamed: "MDD S2 TASK.edf" to "MDD_S02_TASK.edf"
# Renamed: "MDD S3 TASK.edf" to "MDD_S03_TASK.edf"
# Renamed: "MDD S8 TASK.edf" to "MDD_S08_TASK.edf"
# Renamed: "H S18 EO.edf" to "H_S18_EO.edf"
# Renamed: "H S11 EC.edf" to "H_S11_EC.edf"
# Renamed: "MDD S19 EC.edf" to "MDD_S19_EC.edf"
# Renamed: "MDD S10 EO.edf" to "MDD_S10_EO.edf"
# Renamed: "H S14 EO.edf" to "H_S14_EO.edf"
# Renamed: "MDD S30 TASK.edf" to "MDD_S30_TASK.edf"
# Renamed: "MDD S31 TASK.edf" to "MDD_S31_TASK.edf"
# Renamed: "MDD S15 EC.edf" to "MDD_S15_EC.edf"
# Renamed: "H S28 TASK.edf" to "H_S28_TASK.edf"
# Renamed: "H S29 TASK.edf" to "H_S29_TASK.edf"
# Renamed: "H S22 EO.edf" to "H_S22_EO.edf"
# Renamed: "H S2 EO.edf" to "H_S02_EO.edf"
# Renamed: "MDD S23 EC.edf" to "MDD_S23_EC.edf"
# Renamed: "MDD S3 EC.edf" to "MDD_S03_EC.edf"
# Renamed: "MDD S34 EO.edf" to "MDD_S34_EO.edf"
# Renamed: "MDD S6 EO.edf" to "MDD_S06_EO.edf"
# Renamed: "H S30 EO.edf" to "H_S30_EO.edf"
# Renamed: "MDD S31 EC.edf" to "MDD_S31_EC.edf"
# Renamed: "H S16 TASK.edf" to "H_S16_TASK.edf"
# Renamed: "H S27 EC.edf" to "H_S27_EC.edf"
# Renamed: "H S17 TASK.edf" to "H_S17_TASK.edf"
# Renamed: "H S7 EC.edf" to "H_S07_EC.edf"
# Renamed: "MDD S26 EO.edf" to "MDD_S26_EO.edf"
# Renamed: "MDD S11  EC.edf" to "MDD_S11_EC.edf"
# Renamed: "H S25 TASK.edf" to "H_S25_TASK.edf"
# Renamed: "H S24 TASK.edf" to "H_S24_TASK.edf"
# Renamed: "MDD S5 TASK.edf" to "MDD_S05_TASK.edf"
# Renamed: "MDD S4 TASK.edf" to "MDD_S04_TASK.edf"
# Renamed: "MDD S2 EO.edf" to "MDD_S02_EO.edf"
# Renamed: "MDD S22 EO.edf" to "MDD_S22_EO.edf"
# Renamed: "H S23 EC.edf" to "H_S23_EC.edf"
# Renamed: "H S3 EC.edf" to "H_S03_EC.edf"
# Renamed: "MDD S27 EC.edf" to "MDD_S27_EC.edf"
# Renamed: "H S26 EO.edf" to "H_S26_EO.edf"
# Renamed: "MDD S1  EO.edf" to "MDD_S01_EO.edf"
# Renamed: "H S6 EO.edf" to "H_S06_EO.edf"
# Renamed: "MDD S30 EO.edf" to "MDD_S30_EO.edf"
# Renamed: "MDD S18 EO.edf" to "MDD_S18_EO.edf"
# Renamed: "H S19 EC.edf" to "H_S19_EC.edf"
# Renamed: "H S10 EO.edf" to "H_S10_EO.edf"
# Renamed: "H S11 TASK.edf" to "H_S11_TASK.edf"
# Renamed: "H S10 TASK.edf" to "H_S10_TASK.edf"
# Renamed: "MDD S14 EO.edf" to "MDD_S14_EO.edf"
# Renamed: "H S15 EC.edf" to "H_S15_EC.edf"
# Renamed: "MDD S32 EO.edf" to "MDD_S32_EO.edf"
# Renamed: "MDD S5 EC.edf" to "MDD_S05_EC.edf"
# Renamed: "MDD S25 EC.edf" to "MDD_S25_EC.edf"
# Renamed: "H S4 EO.edf" to "H_S04_EO.edf"
# Renamed: "H S24 EO.edf" to "H_S24_EO.edf"
# Renamed: "H S1 TASK.edf" to "H_S01_TASK.edf"
# Renamed: "MDD S29 EC.edf" to "MDD_S29_EC.edf"
# Renamed: "MDD S20 EO.edf" to "MDD_S20_EO.edf"
# Renamed: "H S1 EC.edf" to "H_S01_EC.edf"
# Renamed: "H S28 EO.edf" to "H_S28_EO.edf"
# Renamed: "H S8 EO.edf" to "H_S08_EO.edf"
# Renamed: "H S21 EC.edf" to "H_S21_EC.edf"
# Renamed: "MDD S9 EC.edf" to "MDD_S09_EC.edf"
# Renamed: "MDD S16 EO.edf" to "MDD_S16_EO.edf"
# Renamed: "H S17 EC.edf" to "H_S17_EC.edf"
# Renamed: "6921959_H S15 EO.edf" to "6921959_H_S15_EO.edf"
# Renamed: "MDD S13 EC.edf" to "MDD_S13_EC.edf"
# Renamed: "MDD S14 TASK.edf" to "MDD_S14_TASK.edf"
# Renamed: "H S12 EO.edf" to "H_S12_EO.edf"
# Renamed: "MDD S15 TASK.edf" to "MDD_S15_TASK.edf"
# Renamed: "MDD S20 TASK.edf" to "MDD_S20_TASK.edf"
# Renamed: "MDD S21 TASK.edf" to "MDD_S21_TASK.edf"
# Renamed: "MDD S33 TASK.edf" to "MDD_S33_TASK.edf"
# Renamed: "MDD S32 TASK.edf" to "MDD_S32_TASK.edf"
# Renamed: "H S15 TASK.edf" to "H_S15_TASK.edf"
# Renamed: "H S14 TASK.edf" to "H_S14_TASK.edf"
# Renamed: "MDD S32 EC.edf" to "MDD_S32_EC.edf"
# Renamed: "MDD S5 EO.edf" to "MDD_S05_EO.edf"
# Renamed: "MDD S25 EO.edf" to "MDD_S25_EO.edf"
# Renamed: "H S4 EC.edf" to "H_S04_EC.edf"
# Renamed: "H S24 EC.edf" to "H_S24_EC.edf"
# Renamed: "MDD S29 EO.edf" to "MDD_S29_EO.edf"
# Renamed: "MDD S20 EC.edf" to "MDD_S20_EC.edf"
# Renamed: "H S1 EO.edf" to "H_S01_EO.edf"
# Renamed: "H S28 EC.edf" to "H_S28_EC.edf"
# Renamed: "H S8 EC.edf" to "H_S08_EC.edf"
# Renamed: "H S21 EO.edf" to "H_S21_EO.edf"
# Renamed: "MDD S9 EO.edf" to "MDD_S09_EO.edf"
# Renamed: "MDD S1 TASK.edf" to "MDD_S01_TASK.edf"
# Renamed: "H S17 EO.edf" to "H_S17_EO.edf"
# Renamed: "MDD S13 EO.edf" to "MDD_S13_EO.edf"
# Renamed: "MDD S22 EC.edf" to "MDD_S22_EC.edf"
# Renamed: "MDD S24 TASK.edf" to "MDD_S24_TASK.edf"
# Renamed: "MDD S25 TASK.edf" to "MDD_S25_TASK.edf"
# Renamed: "H S23 EO.edf" to "H_S23_EO.edf"
# Renamed: "H S3 EO.edf" to "H_S03_EO.edf"
# Renamed: "MDD S27 EO.edf" to "MDD_S27_EO.edf"
# Renamed: "H S26 EC.edf" to "H_S26_EC.edf"
# Renamed: "H S6 EC.edf" to "H_S06_EC.edf"
# Renamed: "MDD S30 EC.edf" to "MDD_S30_EC.edf"
# Renamed: "MDD S18 EC.edf" to "MDD_S18_EC.edf"
# Renamed: "MDD S11 EO.edf" to "MDD_S11_EO.edf"
# Renamed: "H S19 EO.edf" to "H_S19_EO.edf"
# Renamed: "H S10 EC.edf" to "H_S10_EC.edf"
# Renamed: "MDD S14 EC.edf" to "MDD_S14_EC.edf"
# Renamed: "H S4 TASK.edf" to "H_S04_TASK.edf"
# Renamed: "H S5 TASK.edf" to "H_S05_TASK.edf"
# Renamed: "MDD S10 TASK.edf" to "MDD_S10_TASK.edf"
# Renamed: "MDD S11 TASK.edf" to "MDD_S11_TASK.edf"
# Renamed: "MDD S23 TASK.edf" to "MDD_S23_TASK.edf"
# Renamed: "MDD S22 TASK.edf" to "MDD_S22_TASK.edf"
# Renamed: "H S11 EO.edf" to "H_S11_EO.edf"
# Renamed: "MDD S19 EO.edf" to "MDD_S19_EO.edf"
# Renamed: "MDD S10 EC.edf" to "MDD_S10_EC.edf"
# Renamed: "H S14 EC.edf" to "H_S14_EC.edf"
# Renamed: "H S9 TASK.edf" to "H_S09_TASK.edf"
# Renamed: "MDD S15 EO.edf" to "MDD_S15_EO.edf"
# Renamed: "H S8 TASK.edf" to "H_S08_TASK.edf"
# Renamed: "H S22 EC.edf" to "H_S22_EC.edf"
# Renamed: "H S2 EC.edf" to "H_S02_EC.edf"
# Renamed: "MDD S23 EO.edf" to "MDD_S23_EO.edf"
# Renamed: "MDD S3 EO.edf" to "MDD_S03_EO.edf"
# Renamed: "MDD S34 EC.edf" to "MDD_S34_EC.edf"
# Renamed: "H S30 EC.edf" to "H_S30_EC.edf"
# Renamed: "MDD S6 EC.edf" to "MDD_S06_EC.edf"
# Renamed: "MDD S31 EO.edf" to "MDD_S31_EO.edf"
# Renamed: "H S27 EO.edf" to "H_S27_EO.edf"
# Renamed: "H S7 EO.edf" to "H_S07_EO.edf"
# Renamed: "MDD S26 EC.edf" to "MDD_S26_EC.edf"
# Renamed: "H S3 TASK.edf" to "H_S03_TASK.edf"
# Renamed: "H S2 TASK.edf" to "H_S02_TASK.edf"
# Renamed: "H S30 TASK.edf" to "H_S30_TASK.edf"
# Renamed: "MDD S29 TASK.edf" to "MDD_S29_TASK.edf"
# Renamed: "MDD S28 TASK.edf" to "MDD_S28_TASK.edf"
# Renamed: "MDD S17 TASK.edf" to "MDD_S17_TASK.edf"
# Renamed: "MDD S16 TASK.edf" to "MDD_S16_TASK.edf"
# Renamed: "MDD S34 TASK.edf" to "MDD_S34_TASK.edf"
# Renamed: "H S12 TASK.edf" to "H_S12_TASK.edf"
# Renamed: "H S13 TASK.edf" to "H_S13_TASK.edf"
# Renamed: "6921143_H S15 EO.edf" to "H_S15_EO.edf"
# Renamed: "H S16 EC.edf" to "H_S16_EC.edf"
# Renamed: "MDD S2  EC.edf" to "MDD_S02_EC.edf"
# Renamed: "MDD S17 EO.edf" to "MDD_S17_EO.edf"
# Renamed: "H S26 TASK.edf" to "H_S26_TASK.edf"
# Renamed: "H S27 TASK.edf" to "H_S27_TASK.edf"
# Renamed: "H S13 EO.edf" to "H_S13_EO.edf"
# Renamed: "MDD S6 TASK.edf" to "MDD_S06_TASK.edf"
# Renamed: "MDD S7 TASK.edf" to "MDD_S07_TASK.edf"
# Renamed: "H S5 EO.edf" to "H_S05_EO.edf"
# Renamed: "H S18 TASK.edf" to "H_S18_TASK.edf"
# Renamed: "H S19 TASK.edf" to "H_S19_TASK.edf"
# Renamed: "MDD S33 EO.edf" to "MDD_S33_EO.edf"
# Renamed: "H S29 EO.edf" to "H_S29_EO.edf"
# Renamed: "H S9 EO.edf" to "H_S09_EO.edf"
# Renamed: "H S20 EC.edf" to "H_S20_EC.edf"
# Renamed: "MDD S28 EC.edf" to "MDD_S28_EC.edf"
# Renamed: "MDD S21 EO.edf" to "MDD_S21_EO.edf"
# Renaming complete.

# %%
all_edf_files = os.listdir(edf_directory)
ec_file_path = [i for i in all_edf_files if i.endswith('EC.edf')]
eo_file_path = [i for i in all_edf_files if i.endswith('EO.edf')]
task_file_path = [i for i in all_edf_files if i.endswith('TASK.edf')]

print(len(all_edf_files), len(ec_file_path),
      len(eo_file_path), len(task_file_path))
# Out:
# 181 58 62 61

# %% [markdown]
# ## Preprocessing Functions

# %%
# Function to rename channels and drop specified channels based on conditions
def process_channels(raw_data):
    """
    Process and standardize EEG channels to keep only the 17 most common channels.
    """
    print(f"Initial channels: {raw_data.ch_names}")

    # Initialize a list to hold channels to drop
    channels_to_drop = []

    # Create mapping for channel renaming
    rename_map = {}
    for name in raw_data.ch_names:
        if any(x in name for x in ['23A-23R', '24A-24R', 'A2-A1']):
            channels_to_drop.append(name)
        else:
            new_name = name.replace('EEG ', '').replace('-LE', '')
            rename_map[name] = new_name

    # Drop unwanted channels
    if channels_to_drop:
        print(f"Dropping channels: {channels_to_drop}")
        raw_data.drop_channels(channels_to_drop)

    # Rename remaining channels
    raw_data.rename_channels(rename_map)

    print(f"Final channels: {raw_data.ch_names}")

    # Define the 17 most common channels
    expected_channels = [
        'Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'Fp2',
        'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz'
    ]

    # Keep only the expected channels
    channels_to_keep = set(expected_channels)
    channels_to_drop = [
        ch for ch in raw_data.ch_names if ch not in channels_to_keep]

    if channels_to_drop:
        print(
            f"Dropping channels to keep only the expected 17 channels: {channels_to_drop}")
        raw_data.drop_channels(channels_to_drop)

    # Verify we have the expected number of channels (should be 17)
    if len(raw_data.ch_names) != len(expected_channels):
        print(
            f"Warning: Expected {len(expected_channels)} channels, got {len(raw_data.ch_names)}")
        print(f"Missing: {set(expected_channels) - set(raw_data.ch_names)}")

    return raw_data

# %%
def read_data(file_path):
    data = mne.io.read_raw_edf(file_path, preload=True)
    data.set_eeg_reference()
    return data

# %%
# Bandpass filtering
def bandpass_filter(data, l_freq, h_freq, notch_freq=None):
    filtered_data = data.copy()

    # Apply bandpass first
    filtered_data.filter(l_freq=l_freq, h_freq=h_freq,
                         method='fir', phase='zero')

    # If using notch, apply with wider bandwidth
    if notch_freq is not None:
        filtered_data.notch_filter(freqs=notch_freq, notch_widths=2.0)

    return filtered_data

# %%
ica_channels = ['Fp1', 'Fp2']

# %%
def preprocess_ICA(epochs, n_components):
    """
    Apply Independent Component Analysis (ICA) to the epochs data.
    
    Parameters:
    -----------
    epochs : mne.Epochs
        The epochs data to process.
    n_components : int
        The number of components to extract.
    
    Returns:
    --------
    ica : ICA
        The fitted ICA object.
    """
    print(
        f"Preprocessing ICA for {len(epochs)} epochs...")  # Print the number of epochs being processed

    ica = ICA(n_components=n_components, random_state=97, max_iter=800)
    # Use the epochs directly
    ica.fit(epochs.copy().pick_channels(ica_channels))
    return ica

# %%
def create_epochs(processed_data, duration=5.0, overlap=1.0):
    """
    Create epochs from continuous EEG data and format for CNN input
    
    Parameters:
    -----------
    processed_data : mne.io.Raw
        The raw EEG data
    duration : float
        Duration of each epoch in seconds
    overlap : float
        Overlap between epochs in seconds
    
    Returns:
    --------
    epochs_array : numpy.ndarray
        The epoched data formatted for CNN (samples, channels, timepoints, 1)
    """

    # Create epochs
    epochs = mne.make_fixed_length_epochs(
        processed_data,
        duration=duration,
        overlap=overlap,
        preload=True
    )

    # Drop bad epochs
    epochs.drop_bad()

    # Get data and reshape for CNN
    # Shape will be (n_epochs, n_channels, n_timepoints)
    data = epochs.get_data()

    # Add channel dimension for CNN: (n_epochs, n_channels, n_timepoints, 1)
    data = data[..., np.newaxis]

    return data

# %%
# Directory containing the EDF files
edf_directory = "./edf_dataset_2"  # Adjust this path to your dataset location

# Initialize lists
processed_raw_data = []
class_counts = {'Healthy': 0, 'MDD': 0}

# Read all EDF files
for filename in os.listdir(edf_directory):
    if filename.endswith('.edf'):
        file_path = os.path.join(edf_directory, filename)
        try:
            # Read the raw data
            raw_data = read_data(file_path)

            if raw_data is not None:
                processed_raw_data.append(raw_data)
                print(f"Successfully loaded: {filename}")
            else:
                print(f"Failed to load: {filename}")

        except Exception as e:
            print(f"Error loading {filename}: {str(e)}")
            continue

print(f"\nTotal files loaded: {len(processed_raw_data)}")
# Out:
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S08_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S08_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S01_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S01_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S09_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S09_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S16_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S16_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S17_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S17_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S13_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S13_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S12_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 48383  =      0.000 ...   188.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S12_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S04_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75519  =      0.000 ...   294.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S04_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S26_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163071  =      0.000 ...   636.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S26_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S27_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S27_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S05_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S05_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S25_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S25_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S24_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S24_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S33_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S33_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S01_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S01_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S20_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 81919  =      0.000 ...   319.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S20_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S18_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S18_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S29_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S29_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S19_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S19_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S21_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S21_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S28_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S28_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S12_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 166143  =      0.000 ...   648.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S12_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S13_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S13_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S31_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S31_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S30_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161023  =      0.000 ...   628.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S30_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S29_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S29_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S28_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S28_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S17_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S17_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S16_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162303  =      0.000 ...   633.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S16_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S06_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S06_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S07_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S07_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S11_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S11_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S18_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S18_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S10_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S10_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S19_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S19_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S23_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 158719  =      0.000 ...   619.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S23_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S22_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154623  =      0.000 ...   603.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S22_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S14_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 49663  =      0.000 ...   193.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S14_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S15_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S15_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S03_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S03_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S02_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S02_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S22_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S22_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S23_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S23_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S34_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75775  =      0.000 ...   295.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S34_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S30_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S30_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S31_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S31_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S27_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S27_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S05_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 157183  =      0.000 ...   613.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S05_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S04_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S04_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S26_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S26_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S10_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S10_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S11_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S11_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S08_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S08_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S22_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S22_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S23_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S23_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S27_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S27_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S26_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S26_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S24_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164863  =      0.000 ...   643.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S24_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S25_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164607  =      0.000 ...   642.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S25_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S30_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S30_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S11_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S11_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S18_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S18_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S10_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S10_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S19_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S19_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S06_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S06_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S07_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 91135  =      0.000 ...   355.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S07_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S03_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 46079  =      0.000 ...   179.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S03_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S02_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S02_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S02_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164863  =      0.000 ...   643.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S02_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S03_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S03_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S14_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S14_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S15_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S15_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S32_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S32_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S25_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S25_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S24_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S24_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S20_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S20_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S29_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S29_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S21_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S21_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S20_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S20_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S21_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S21_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S28_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S28_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S16_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S16_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S17_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79103  =      0.000 ...   308.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S17_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S01_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S01_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S09_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S09_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/6921959_H_S15_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: 6921959_H_S15_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S04_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S04_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S05_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S05_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S07_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S07_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S06_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156415  =      0.000 ...   610.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S06_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S13_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S13_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S12_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S12_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S15_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 160511  =      0.000 ...   626.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S15_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S14_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162559  =      0.000 ...   634.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S14_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S06_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163583  =      0.000 ...   638.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S06_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S07_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162815  =      0.000 ...   635.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S07_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S32_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S32_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S32_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 160767  =      0.000 ...   627.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S32_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S33_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 168447  =      0.000 ...   657.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S33_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S25_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S25_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S24_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S24_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S20_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S20_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S29_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S29_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S21_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S21_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S28_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S28_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S17_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S17_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S01_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S01_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S09_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S09_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S14_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155391  =      0.000 ...   606.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S14_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S15_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S15_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S05_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79871  =      0.000 ...   311.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S05_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S13_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 79615  =      0.000 ...   310.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S13_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S22_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S22_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S23_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S23_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S27_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S27_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S26_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S26_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S30_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 61695  =      0.000 ...   240.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S30_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S11_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S11_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S18_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# ...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S19_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S14_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S14_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S15_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S15_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S03_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78079  =      0.000 ...   304.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S03_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S02_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76031  =      0.000 ...   296.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S02_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S22_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S22_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S23_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78591  =      0.000 ...   306.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S23_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S16_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 163327  =      0.000 ...   637.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S16_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S17_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161535  =      0.000 ...   630.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S17_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S34_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76287  =      0.000 ...   297.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S34_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S30_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S30_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S31_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S31_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S27_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S27_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S26_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S26_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S22_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 164095  =      0.000 ...   640.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S22_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S23_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S23_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S04_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S04_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S05_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156671  =      0.000 ...   611.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S05_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S27_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 162047  =      0.000 ...   632.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S27_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S26_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156415  =      0.000 ...   610.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S26_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S01_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 161791  =      0.000 ...   631.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S01_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S19_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155647  =      0.000 ...   607.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S19_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S18_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 155647  =      0.000 ...   607.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S18_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S08_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S08_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S01_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 89855  =      0.000 ...   350.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S01_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S09_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S09_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S16_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 74751  =      0.000 ...   291.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S16_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S34_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 168447  =      0.000 ...   657.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S34_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S17_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76543  =      0.000 ...   298.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S17_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S13_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77567  =      0.000 ...   302.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S13_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S04_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S04_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S05_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77311  =      0.000 ...   301.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S05_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S24_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S24_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S13_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 156159  =      0.000 ...   609.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S13_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S12_TASK.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 154879  =      0.000 ...   604.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S12_TASK.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S33_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75775  =      0.000 ...   295.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S33_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S20_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 78591  =      0.000 ...   306.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S20_EC.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/H_S29_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: H_S29_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S21_EO.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 76799  =      0.000 ...   299.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S21_EO.edf
# Extracting EDF parameters from /Users/hansandreanto/Development/capstone-project/core/edf_dataset_2/MDD_S28_EC.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 77055  =      0.000 ...   300.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Successfully loaded: MDD_S28_EC.edf
#
# Total files loaded: 181

# %%
# The actual preprocessing data
def preprocess_eeg(raw_data, l_freq=0.5, h_freq=60.0, notch_freq=50.0, n_components=2, epoch_duration=5.0, epoch_overlap=1.0):
    """
    Complete EEG preprocessing pipeline: filter -> bad channel removal -> epoching -> ICA -> baseline correction
    """
    try:
        # print(f"\nProcessing file: {filename}")

        # Make a copy of the raw data to prevent modifications to original
        processed_raw = raw_data.copy()

        # 1. Bandpass filtering
        print("1. Applying bandpass filter...")
        try:
            bandpass_filter(processed_raw, l_freq, h_freq, notch_freq)
            print("Bandpass filtering completed")
        except Exception as e:
            print(f"Error during bandpass filtering: {str(e)}")
            return None

        # 2. Bad channel removal
        print("2. Removing bad channels...")
        try:
            processed_raw = process_channels(raw_data=processed_raw)
            print("Bad channels removed")
        except Exception as e:
            print(f"Error during bad channel removal: {str(e)}")
            return None

        # 3. Epoching
        print("3. Creating epochs...")
        try:
            epochs = mne.make_fixed_length_epochs(
                processed_raw,
                duration=epoch_duration,
                overlap=epoch_overlap,
                preload=True
            )

            # Drop bad epochs
            epochs.drop_bad()

            # Get data and reshape for CNN
            data = epochs.get_data()
            data = data[..., np.newaxis]  # Add channel dimension for CNN

            print(f"Epoching completed. Final data shape: {data.shape}")
        except Exception as e:
            print(f"Error during epoching: {str(e)}")
            return None

        # 4. ICA
        print("4. Applying ICA...")
        try:
            # Pass the epochs object
            ica = preprocess_ICA(epochs, n_components)
            ica.apply(epochs)  # Apply ICA to the epochs
            print("ICA completed")
        except Exception as e:
            print(f"Error during ICA: {str(e)}")
            return None

        # 5. Baseline correction
        print("5. Applying baseline correction...")
        try:
            # Apply baseline correction over the entire epoch
            epochs.apply_baseline((None, None))
            print("Baseline correction completed")
        except Exception as e:
            print(f"Error during baseline correction: {str(e)}")
            return None

        return data  # Return the processed data

    except Exception as e:
        print(f"General preprocessing error: {str(e)}")
        return None

# %%
# Now process each raw data file
X_data = []
y_labels = []
class_counts = {'Healthy': 0, 'MDD': 0}

print("\nStarting preprocessing pipeline...")
for raw_data in processed_raw_data:
    # Get the filename from the raw data
    filename = os.path.basename(raw_data.filenames[0])
    print(f"\n{'='*50}")
    print(f"Processing: {filename}")
    print(f"Initial data info:")
    print(f"Channels: {raw_data.ch_names}")
    print(f"Sample rate: {raw_data.info['sfreq']} Hz")
    print(f"Duration: {raw_data.n_times / raw_data.info['sfreq']:.2f} seconds")

    # Apply complete preprocessing pipeline
    try:
        # Apply complete preprocessing pipeline
        processed_data = preprocess_eeg(
            raw_data,

            l_freq=0.5,
            h_freq=50.0,
            n_components=2,
            notch_freq=50.0,
            epoch_duration=5.0,
            epoch_overlap=1.0
        )

        if processed_data is not None:
            print(f"Processed data shape: {processed_data.shape}")

            # Create label (1 for MDD, 0 for Healthy)
            label = 1 if filename.startswith('MDD') else 0

            # Update counts with number of epochs
            if label == 1:
                class_counts['MDD'] += processed_data.shape[0]
            else:
                class_counts['Healthy'] += processed_data.shape[0]

            # Append to lists
            X_data.append(processed_data)
            y_labels.extend([label] * processed_data.shape[0])
            print(f"Successfully processed {filename}")
        else:
            print(f"Failed to process {filename}")

    except Exception as e:
        print(f"Error processing {filename}: {str(e)}")
        continue

    print(f"{'='*50}\n")


# Print final summary
print("\nProcessing Summary:")
print(f"Total files processed: {len(processed_raw_data)}")
print(f"Total epochs: {len(y_labels)}")
print(f"Successfully processed files: {len(X_data)}")
print(f"Failed files: {len(processed_raw_data) - len(X_data)}")
print("\nClass distribution:")
print(f"MDD epochs: {class_counts['MDD']}")
print(f"Healthy epochs: {class_counts['Healthy']}")
# Out:
# Starting preprocessing pipeline...
#
# ==================================================
# Processing: H_S08_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 302.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (75, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 75 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# Fitting ICA took 0.8s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (75, 17, 1280, 1)
# Successfully processed H_S08_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S01_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 300.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed H_S01_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S09_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 300.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Selecting by number: 2 components
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed MDD_S09_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S16_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 299.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed H_S16_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S17_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 297.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Selecting by number: 2 components
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed MDD_S17_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S13_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 300.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed H_S13_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S12_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 189.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 47 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 47 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (47, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 47 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.0s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (47, 17, 1280, 1)
# Successfully processed MDD_S12_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S04_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 295.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 73 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (73, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 73 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (73, 17, 1280, 1)
# Successfully processed H_S04_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S26_TASK.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 637.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 159 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 159 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (159, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 159 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.8s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (159, 17, 1280, 1)
# Successfully processed MDD_S26_TASK.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S27_TASK.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 610.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 152 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 152 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (152, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 152 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (152, 17, 1280, 1)
# Successfully processed MDD_S27_TASK.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S05_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 302.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (75, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 75 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (75, 17, 1280, 1)
# Successfully processed MDD_S05_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S25_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 301.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (75, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 75 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (75, 17, 1280, 1)
# Successfully processed H_S25_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S24_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 300.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed MDD_S24_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S33_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 298.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed MDD_S33_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S01_TASK.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 605.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# ...
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 73 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (73, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 73 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (73, 17, 1280, 1)
# Successfully processed MDD_S33_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S20_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 307.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 76 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (76, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 76 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Selecting by number: 2 components
# Fitting ICA took 0.3s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (76, 17, 1280, 1)
# Successfully processed H_S20_EC.edf
# ==================================================
#
#
# ==================================================
# Processing: H_S29_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Sample rate: 256.0 Hz
# Duration: 301.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Dropping channels: ['EEG A2-A1', 'EEG 23A-23R', 'EEG 24A-24R']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (75, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 75 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (75, 17, 1280, 1)
# Successfully processed H_S29_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S21_EO.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 300.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (74, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 74 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (74, 17, 1280, 1)
# Successfully processed MDD_S21_EO.edf
# ==================================================
#
#
# ==================================================
# Processing: MDD_S28_EC.edf
# Initial data info:
# Channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Sample rate: 256.0 Hz
# Duration: 301.00 seconds
# 1. Applying bandpass filter...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 48 - 52 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.25 Hz)
# - Upper passband edge: 51.50 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Bandpass filtering completed
# 2. Removing bad channels...
# Initial channels: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
# Dropping channels: ['EEG A2-A1']
# Final channels: ['Fp1', 'F3', 'C3', 'P3', 'O1', 'F7', 'T3', 'T5', 'Fz', 'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'Cz', 'Pz']
# Dropping channels to keep only the expected 17 channels: ['T5', 'Fz']
# Bad channels removed
# 3. Creating epochs...
# Not setting metadata
# 75 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 75 events and 1280 original time points ...
# 0 bad epochs dropped
# Epoching completed. Final data shape: (75, 17, 1280, 1)
# 4. Applying ICA...
# Preprocessing ICA for 75 epochs...
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Fitting ICA to data using 2 channels (please be patient, this may take a while)
# Selecting by number: 2 components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Fitting ICA took 0.2s.
# Applying ICA to Epochs instance
#     Transforming to ICA space (2 components)
#     Zeroing out 0 ICA components
#     Projecting back using 2 PCA components
# ICA completed
# 5. Applying baseline correction...
# Applying baseline correction (mode: mean)
# Baseline correction completed
# Processed data shape: (75, 17, 1280, 1)
# Successfully processed MDD_S28_EC.edf
# ==================================================
#
#
# Processing Summary:
# Total files processed: 181
# Total epochs: 18387
# Successfully processed files: 181
# Failed files: 0
#
# Class distribution:
# MDD epochs: 9756
# Healthy epochs: 8631

# %%
# Check if we have any processed data
if len(X_data) > 0:
    try:
        # Print shapes before concatenation
        print("\nArray shapes before concatenation:")
        for i, arr in enumerate(X_data):
            print(f"Array {i}: shape {arr.shape}")

        # Concatenate data
        X = np.concatenate(X_data, axis=0)
        y = np.array(y_labels)

        # Print final information
        print("\nFinal Dataset Information:")
        print(f"Total samples: {len(X)}")
        print(f"Healthy samples: {class_counts['Healthy']}")
        print(f"MDD samples: {class_counts['MDD']}")
        print(f"Input shape: {X.shape}")
        print(f"Labels shape: {y.shape}")

        # Print channel information
        print(f"\nChannels used: {raw_data.ch_names}")

        # Print class balance
        total_epochs = class_counts['MDD'] + class_counts['Healthy']
        print("\nClass balance:")
        print(f"MDD: {(class_counts['MDD']/total_epochs)*100:.2f}%")
        print(f"Healthy: {(class_counts['Healthy']/total_epochs)*100:.2f}%")

    except Exception as e:
        print(f"\nError during final processing: {str(e)}")
        print("Checking individual arrays for inconsistencies...")

        # Find arrays with different shapes
        base_shape = X_data[0].shape[1:]
        for i, arr in enumerate(X_data):
            if arr.shape[1:] != base_shape:
                print(
                    f"Mismatch at index {i}: expected {base_shape}, got {arr.shape[1:]}")
else:
    print("\nNo data was successfully processed!")
# Out:
# Array shapes before concatenation:
# Array 0: shape (75, 17, 1280, 1)
# Array 1: shape (74, 17, 1280, 1)
# Array 2: shape (74, 17, 1280, 1)
# Array 3: shape (74, 17, 1280, 1)
# Array 4: shape (74, 17, 1280, 1)
# Array 5: shape (74, 17, 1280, 1)
# Array 6: shape (47, 17, 1280, 1)
# Array 7: shape (73, 17, 1280, 1)
# Array 8: shape (159, 17, 1280, 1)
# Array 9: shape (152, 17, 1280, 1)
# Array 10: shape (75, 17, 1280, 1)
# Array 11: shape (75, 17, 1280, 1)
# Array 12: shape (74, 17, 1280, 1)
# Array 13: shape (74, 17, 1280, 1)
# Array 14: shape (151, 17, 1280, 1)
# Array 15: shape (79, 17, 1280, 1)
# Array 16: shape (158, 17, 1280, 1)
# Array 17: shape (75, 17, 1280, 1)
# Array 18: shape (158, 17, 1280, 1)
# Array 19: shape (74, 17, 1280, 1)
# Array 20: shape (75, 17, 1280, 1)
# Array 21: shape (162, 17, 1280, 1)
# Array 22: shape (157, 17, 1280, 1)
# Array 23: shape (158, 17, 1280, 1)
# Array 24: shape (157, 17, 1280, 1)
# Array 25: shape (151, 17, 1280, 1)
# Array 26: shape (151, 17, 1280, 1)
# Array 27: shape (151, 17, 1280, 1)
# Array 28: shape (158, 17, 1280, 1)
# Array 29: shape (75, 17, 1280, 1)
# Array 30: shape (74, 17, 1280, 1)
# Array 31: shape (74, 17, 1280, 1)
# Array 32: shape (75, 17, 1280, 1)
# Array 33: shape (74, 17, 1280, 1)
# Array 34: shape (74, 17, 1280, 1)
# Array 35: shape (154, 17, 1280, 1)
# Array 36: shape (150, 17, 1280, 1)
# Array 37: shape (48, 17, 1280, 1)
# Array 38: shape (74, 17, 1280, 1)
# Array 39: shape (75, 17, 1280, 1)
# Array 40: shape (74, 17, 1280, 1)
# Array 41: shape (74, 17, 1280, 1)
# Array 42: shape (75, 17, 1280, 1)
# Array 43: shape (73, 17, 1280, 1)
# Array 44: shape (74, 17, 1280, 1)
# Array 45: shape (75, 17, 1280, 1)
# Array 46: shape (74, 17, 1280, 1)
# Array 47: shape (153, 17, 1280, 1)
# Array 48: shape (158, 17, 1280, 1)
# Array 49: shape (74, 17, 1280, 1)
# Array 50: shape (151, 17, 1280, 1)
# Array 51: shape (151, 17, 1280, 1)
# Array 52: shape (151, 17, 1280, 1)
# Array 53: shape (74, 17, 1280, 1)
# Array 54: shape (75, 17, 1280, 1)
# Array 55: shape (75, 17, 1280, 1)
# Array 56: shape (76, 17, 1280, 1)
# Array 57: shape (160, 17, 1280, 1)
# Array 58: shape (160, 17, 1280, 1)
# Array 59: shape (74, 17, 1280, 1)
# Array 60: shape (74, 17, 1280, 1)
# Array 61: shape (75, 17, 1280, 1)
# Array 62: shape (74, 17, 1280, 1)
# Array 63: shape (74, 17, 1280, 1)
# Array 64: shape (75, 17, 1280, 1)
# Array 65: shape (88, 17, 1280, 1)
# Array 66: shape (44, 17, 1280, 1)
# Array 67: shape (75, 17, 1280, 1)
# Array 68: shape (160, 17, 1280, 1)
# Array 69: shape (157, 17, 1280, 1)
# Array 70: shape (75, 17, 1280, 1)
# Array 71: shape (74, 17, 1280, 1)
# Array 72: shape (74, 17, 1280, 1)
# Array 73: shape (74, 17, 1280, 1)
# Array 74: shape (74, 17, 1280, 1)
# Array 75: shape (75, 17, 1280, 1)
# Array 76: shape (74, 17, 1280, 1)
# Array 77: shape (157, 17, 1280, 1)
# Array 78: shape (157, 17, 1280, 1)
# Array 79: shape (75, 17, 1280, 1)
# Array 80: shape (74, 17, 1280, 1)
# Array 81: shape (74, 17, 1280, 1)
# Array 82: shape (77, 17, 1280, 1)
# Array 83: shape (75, 17, 1280, 1)
# Array 84: shape (75, 17, 1280, 1)
# Array 85: shape (75, 17, 1280, 1)
# Array 86: shape (75, 17, 1280, 1)
# Array 87: shape (75, 17, 1280, 1)
# Array 88: shape (151, 17, 1280, 1)
# Array 89: shape (152, 17, 1280, 1)
# Array 90: shape (74, 17, 1280, 1)
# Array 91: shape (74, 17, 1280, 1)
# Array 92: shape (156, 17, 1280, 1)
# Array 93: shape (158, 17, 1280, 1)
# Array 94: shape (159, 17, 1280, 1)
# Array 95: shape (158, 17, 1280, 1)
# Array 96: shape (74, 17, 1280, 1)
# Array 97: shape (156, 17, 1280, 1)
# Array 98: shape (164, 17, 1280, 1)
# Array 99: shape (74, 17, 1280, 1)
# Array 100: shape (74, 17, 1280, 1)
# Array 101: shape (74, 17, 1280, 1)
# Array 102: shape (74, 17, 1280, 1)
# Array 103: shape (76, 17, 1280, 1)
# Array 104: shape (75, 17, 1280, 1)
# Array 105: shape (75, 17, 1280, 1)
# Array 106: shape (75, 17, 1280, 1)
# Array 107: shape (75, 17, 1280, 1)
# Array 108: shape (151, 17, 1280, 1)
# Array 109: shape (152, 17, 1280, 1)
# Array 110: shape (77, 17, 1280, 1)
# Array 111: shape (77, 17, 1280, 1)
# Array 112: shape (74, 17, 1280, 1)
# Array 113: shape (75, 17, 1280, 1)
# Array 114: shape (74, 17, 1280, 1)
# Array 115: shape (75, 17, 1280, 1)
# Array 116: shape (60, 17, 1280, 1)
# Array 117: shape (74, 17, 1280, 1)
# Array 118: shape (74, 17, 1280, 1)
# Array 119: shape (159, 17, 1280, 1)
# Array 120: shape (171, 17, 1280, 1)
# Array 121: shape (93, 17, 1280, 1)
# Array 122: shape (75, 17, 1280, 1)
# Array 123: shape (150, 17, 1280, 1)
# Array 124: shape (75, 17, 1280, 1)
# Array 125: shape (152, 17, 1280, 1)
# Array 126: shape (75, 17, 1280, 1)
# Array 127: shape (75, 17, 1280, 1)
# Array 128: shape (75, 17, 1280, 1)
# Array 129: shape (74, 17, 1280, 1)
# Array 130: shape (75, 17, 1280, 1)
# Array 131: shape (156, 17, 1280, 1)
# Array 132: shape (158, 17, 1280, 1)
# Array 133: shape (151, 17, 1280, 1)
# Array 134: shape (151, 17, 1280, 1)
# Array 135: shape (75, 17, 1280, 1)
# Array 136: shape (158, 17, 1280, 1)
# Array 137: shape (75, 17, 1280, 1)
# Array 138: shape (157, 17, 1280, 1)
# Array 139: shape (75, 17, 1280, 1)
# Array 140: shape (157, 17, 1280, 1)
# Array 141: shape (74, 17, 1280, 1)
# Array 142: shape (75, 17, 1280, 1)
# Array 143: shape (74, 17, 1280, 1)
# Array 144: shape (76, 17, 1280, 1)
# Array 145: shape (74, 17, 1280, 1)
# Array 146: shape (75, 17, 1280, 1)
# Array 147: shape (76, 17, 1280, 1)
# Array 148: shape (159, 17, 1280, 1)
# Array 149: shape (157, 17, 1280, 1)
# Array 150: shape (74, 17, 1280, 1)
# Array 151: shape (74, 17, 1280, 1)
# Array 152: shape (75, 17, 1280, 1)
# Array 153: shape (74, 17, 1280, 1)
# Array 154: shape (74, 17, 1280, 1)
# Array 155: shape (160, 17, 1280, 1)
# Array 156: shape (157, 17, 1280, 1)
# Array 157: shape (151, 17, 1280, 1)
# Array 158: shape (152, 17, 1280, 1)
# Array 159: shape (158, 17, 1280, 1)
# Array 160: shape (152, 17, 1280, 1)
# Array 161: shape (157, 17, 1280, 1)
# Array 162: shape (151, 17, 1280, 1)
# Array 163: shape (151, 17, 1280, 1)
# Array 164: shape (75, 17, 1280, 1)
# Array 165: shape (87, 17, 1280, 1)
# Array 166: shape (74, 17, 1280, 1)
# Array 167: shape (72, 17, 1280, 1)
# Array 168: shape (164, 17, 1280, 1)
# Array 169: shape (74, 17, 1280, 1)
# Array 170: shape (75, 17, 1280, 1)
# Array 171: shape (75, 17, 1280, 1)
# Array 172: shape (75, 17, 1280, 1)
# Array 173: shape (75, 17, 1280, 1)
# Array 174: shape (152, 17, 1280, 1)
# Array 175: shape (151, 17, 1280, 1)
# Array 176: shape (73, 17, 1280, 1)
# Array 177: shape (76, 17, 1280, 1)
# Array 178: shape (75, 17, 1280, 1)
# Array 179: shape (74, 17, 1280, 1)
# Array 180: shape (75, 17, 1280, 1)
#
# Final Dataset Information:
# Total samples: 18387
# Healthy samples: 8631
# MDD samples: 9756
# Input shape: (18387, 17, 1280, 1)
# Labels shape: (18387,)
#
# Channels used: ['EEG Fp1-LE', 'EEG F3-LE', 'EEG C3-LE', 'EEG P3-LE', 'EEG O1-LE', 'EEG F7-LE', 'EEG T3-LE', 'EEG T5-LE', 'EEG Fz-LE', 'EEG Fp2-LE', 'EEG F4-LE', 'EEG C4-LE', 'EEG P4-LE', 'EEG O2-LE', 'EEG F8-LE', 'EEG T4-LE', 'EEG T6-LE', 'EEG Cz-LE', 'EEG Pz-LE', 'EEG A2-A1']
#
# Class balance:
# MDD: 53.06%
# Healthy: 46.94%
